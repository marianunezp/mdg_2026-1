# %% [markdown]
# ##Trabajo 1: Analisis geodemografico censo 2017 Gran- Santiago
#
# alumna: María Núñez
# Docente: Matías Escudero
# Laboratorio MDG
#
# ## 1.Introducción
# En chile existe blablabla (como una introducción)
# ## 2.Objetivos
# -- Generar un analisis geodemografico etcetc
# ## 3.Desarrollo
# ### primero siempre poner las librerias

# %%
import geopandas as gpd
from sql_alchemy import create_engine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import geopandas as gpd
#       2 from sql_alchemy import create_engine
#
# ModuleNotFoundError: No module named 'geopandas'
